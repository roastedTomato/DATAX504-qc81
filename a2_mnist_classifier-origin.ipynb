# %% [markdown]
# # Assignment 2 — Keras MNIST Classifier
#
# **DATAX504** · Due end of Week 4
#
# ## Tasks
# 1. Dense classifier on MNIST — test accuracy **without** dropout
# 2. Same architecture **with** dropout — compare train vs val curves
# 3. Confusion matrix → worst confused digit pair
# 4. Explain why `sparse_categorical_crossentropy` is appropriate
#
# ## Moodle fields
# `a2_repo`, `a2_test_acc`, `a2_test_acc_do`, `a2_worst_pair`, `a2_crossentropy`

# %% [markdown]
# ## AI disclosure
#
# | Field | Your answer                                                                                                                                                                                                                                                                          |
# |-------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | Tool | OpenCode Zen + Big Pickle                                                                                                                                                                                                                                                            |
# | Used for | Code debugging, runtime error analysis, code review, checking matrix dimensions and NumPy broadcasting, and identifying potential issues in forward/backward propagation.                                                                                                            |
# | Verified how | All suggestions were manually reviewed before acceptance. The program was re-run after each change, and correctness was verified by successful execution, decreasing training loss, improving classification accuracy, and comparing the implementation with the assignment requirements. |
# | Not used for | Generating the complete neural network implementation, writing the core algorithms from scratch, or producing the final solution without manual development.                                                                                                                         |

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import keras
from keras import layers

# %% [markdown]
# ## 1. Load MNIST

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

x_train_flat = x_train.reshape(-1, 28 * 28)
x_test_flat = x_test.reshape(-1, 28 * 28)

num_classes = 10
print(x_train_flat.shape, y_train.shape)
# Out:
# (60000, 784) (60000,)

# %% [markdown]
# ## 2. Validation split

# %%
val_samples = 10000
x_val = x_train_flat[:val_samples]
y_val = y_train[:val_samples]
x_train_flat = x_train_flat[val_samples:]
y_train = y_train[val_samples:]

print("Train:", x_train_flat.shape[0], "Val:", x_val.shape[0], "Test:", x_test_flat.shape[0])
# Out:
# Train: 50000 Val: 10000 Test: 10000

# %% [markdown]
# ## 3. Model builder
#
# TODO: adjust hidden units if needed. Keep architecture comparable between runs.

# %%
def build_model(use_dropout=False, dropout_rate=0.3):
    model = keras.Sequential([
        layers.Input(shape=(784,)),
        layers.Dense(512, activation="relu"),
        layers.Dense(256, activation="relu"),
    ])
    if use_dropout:
        model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(num_classes, activation="softmax"))
    model.compile(
        optimizer="adam",
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ## 4. Train baseline (no dropout)

# %%
EPOCHS = 20
BATCH_SIZE = 128

model_baseline = build_model(use_dropout=False)
history_baseline = model_baseline.fit(
    x_train_flat, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_val, y_val),
    verbose=1,
)

test_loss, test_acc = model_baseline.evaluate(x_test_flat, y_test, verbose=0)
print(f"Baseline test accuracy (Moodle a2_test_acc): {test_acc:.4f}")
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9280 - loss: 0.2507 - val_accuracy: 0.9614 - val_loss: 0.1268
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9733 - loss: 0.0888 - val_accuracy: 0.9720 - val_loss: 0.0936
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9823 - loss: 0.0564 - val_accuracy: 0.9767 - val_loss: 0.0782
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0381 - val_accuracy: 0.9756 - val_loss: 0.0839
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0277 - val_accuracy: 0.9771 - val_loss: 0.0801
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9938 - loss: 0.0192 - val_accuracy: 0.9706 - val_loss: 0.1085
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9937 - loss: 0.0183 - val_accuracy: 0.9789 - val_loss: 0.0854
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9946 - loss: 0.0165 - val_accuracy: 0.9686 - val_loss: 0.1281
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0162 - val_accuracy: 0.9791 - val_loss: 0.0951
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9971 - loss: 0.0093 - val_accuracy: 0.9806 - val_loss: 0.0828
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9968 - loss: 0.0095 - val_accuracy: 0.9753 - val_loss: 0.1186
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9961 - loss: 0.0127 - val_accuracy: 0.9781 - val_loss: 0.0920
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0080 - val_accuracy: 0.9773 - val_loss: 0.1086
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9962 - loss: 0.0110 - val_accuracy: 0.9811 - val_loss: 0.0953
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9800 - val_loss: 0.0972
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9793 - val_loss: 0.1068
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9967 - loss: 0.0100 - val_accuracy: 0.9723 - val_loss: 0.1465
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9961 - loss: 0.0112 - val_accuracy: 0.9802 - val_loss: 0.1141
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9978 - loss: 0.0076 - val_accuracy: 0.9795 - val_loss: 0.1059
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9979 - loss: 0.0064 - val_accuracy: 0.9801 - val_loss: 0.0991
# Baseline test accuracy (Moodle a2_test_acc): 0.9806

# %% [markdown]
# ## 5. Train with dropout

# %%
model_dropout = build_model(use_dropout=True, dropout_rate=0.3)
history_dropout = model_dropout.fit(
    x_train_flat, y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(x_val, y_val),
    verbose=1,
)

_, test_acc_do = model_dropout.evaluate(x_test_flat, y_test, verbose=0)
print(f"Dropout test accuracy (Moodle a2_test_acc_do): {test_acc_do:.4f}")
# Out:
# Epoch 1/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9197 - loss: 0.2715 - val_accuracy: 0.9616 - val_loss: 0.1281
# Epoch 2/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9693 - loss: 0.1029 - val_accuracy: 0.9724 - val_loss: 0.0943
# Epoch 3/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9781 - loss: 0.0684 - val_accuracy: 0.9754 - val_loss: 0.0794
# Epoch 4/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9854 - loss: 0.0473 - val_accuracy: 0.9777 - val_loss: 0.0779
# Epoch 5/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9877 - loss: 0.0360 - val_accuracy: 0.9780 - val_loss: 0.0773
# Epoch 6/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0276 - val_accuracy: 0.9782 - val_loss: 0.0813
# Epoch 7/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0244 - val_accuracy: 0.9783 - val_loss: 0.0823
# Epoch 8/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9939 - loss: 0.0177 - val_accuracy: 0.9791 - val_loss: 0.0762
# Epoch 9/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9946 - loss: 0.0164 - val_accuracy: 0.9824 - val_loss: 0.0724
# Epoch 10/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0143 - val_accuracy: 0.9799 - val_loss: 0.0810
# Epoch 11/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9945 - loss: 0.0157 - val_accuracy: 0.9807 - val_loss: 0.0765
# Epoch 12/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9959 - loss: 0.0117 - val_accuracy: 0.9777 - val_loss: 0.0982
# Epoch 13/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9962 - loss: 0.0122 - val_accuracy: 0.9765 - val_loss: 0.1054
# Epoch 14/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9957 - loss: 0.0128 - val_accuracy: 0.9809 - val_loss: 0.0933
# Epoch 15/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9956 - loss: 0.0117 - val_accuracy: 0.9783 - val_loss: 0.1087
# Epoch 16/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9970 - loss: 0.0090 - val_accuracy: 0.9822 - val_loss: 0.0870
# Epoch 17/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9972 - loss: 0.0079 - val_accuracy: 0.9799 - val_loss: 0.1088
# Epoch 18/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9966 - loss: 0.0104 - val_accuracy: 0.9778 - val_loss: 0.1089
# Epoch 19/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9798 - val_loss: 0.0990
# Epoch 20/20
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0118 - val_accuracy: 0.9807 - val_loss: 0.0972
# Dropout test accuracy (Moodle a2_test_acc_do): 0.9814

# %% [markdown]
# ## 6. Compare learning curves

# %%
def plot_histories(histories, labels, metric="loss"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    for hist, label in zip(histories, labels):
        axes[0].plot(hist.history[metric], label=f"{label} train")
        axes[0].plot(hist.history[f"val_{metric}"], linestyle="--", label=f"{label} val")
    axes[0].set_xlabel("Epoch")
    axes[0].set_ylabel(metric)
    axes[0].legend()
    axes[0].set_title(f"Training vs validation {metric}")
    axes[0].grid(True, alpha=0.3)
    # accuracy panel
    for hist, label in zip(histories, labels):
        axes[1].plot(hist.history["accuracy"], label=f"{label} train")
        axes[1].plot(hist.history["val_accuracy"], linestyle="--", label=f"{label} val")
    axes[1].set_xlabel("Epoch")
    axes[1].set_ylabel("accuracy")
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_histories([history_baseline, history_dropout], ["baseline", "dropout"])

# %% [markdown]
# ## 7. Confusion matrix

# %%
y_pred = np.argmax(model_dropout.predict(x_test_flat, verbose=0), axis=1)
cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(8, 7))
im = ax.imshow(cm, cmap="Blues")
plt.colorbar(im)
ax.set_xlabel("Predicted")
ax.set_ylabel("True")
ax.set_title("MNIST confusion matrix (dropout model)")
plt.show()

# TODO: find off-diagonal maximum → worst pair for Moodle a2_worst_pair
cm_off = cm.copy()
np.fill_diagonal(cm_off, 0)
true_i, pred_j = np.unravel_index(np.argmax(cm_off), cm_off.shape)
print(f"Worst confused pair (Moodle a2_worst_pair): {true_i}-{pred_j} ({cm_off[true_i, pred_j]} errors)")
# Out:
# Worst confused pair (Moodle a2_worst_pair): 4-9 (11 errors)

# %% [markdown]
# ## 8. Why sparse categorical crossentropy? (Moodle `a2_crossentropy`)
#
# Write up to 150 words explaining:
# - What integer labels look like vs one-hot
# - What the loss computes
# - Why this pairs with a softmax output

# %% [markdown]
# *Your answer here.*
